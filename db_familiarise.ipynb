# %%
import pandas as pd

def read_csv(filename):
    df_csv = pd.read_csv(filename)
    return df_csv

# %%
filename = 'loan_payments.csv'
loan_payments_df = read_csv(filename)

# %%
loan_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54231 entries, 0 to 54230
# Data columns (total 44 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   54231 non-null  int64
#  1   id                           54231 non-null  int64
#  2   member_id                    54231 non-null  int64
#  3   loan_amount                  54231 non-null  int64
#  4   funded_amount                51224 non-null  float64
#  5   funded_amount_inv            54231 non-null  float64
#  6   term                         49459 non-null  object
#  7   int_rate                     49062 non-null  float64
#  8   instalment                   54231 non-null  float64
#  9   grade                        54231 non-null  object
#  10  sub_grade                    54231 non-null  object
#  11  employment_length            52113 non-null  object
#  12  home_ownership               54231 non-null  object
#  13  annual_inc                   54231 non-null  float64
#  14  verification_status          54231 non-null  object
#  15  issue_date                   54231 non-null  object
#  16  loan_status                  54231 non-null  object
#  17  payment_plan                 54231 non-null  object
#  18  purpose                      54231 non-null  object
#  19  dti                          54231 non-null  float64
#  20  delinq_2yrs                  54231 non-null  int64
#  21  earliest_credit_line         54231 non-null  object
#  22  inq_last_6mths               54231 non-null  int64
#  23  mths_since_last_delinq       23229 non-null  float64
#  24  mths_since_last_record       6181 non-null   float64
#  25  open_accounts                54231 non-null  int64
#  26  total_accounts               54231 non-null  int64
#  27  out_prncp                    54231 non-null  float64
#  28  out_prncp_inv                54231 non-null  float64
#  29  total_payment                54231 non-null  float64
#  30  total_payment_inv            54231 non-null  float64
#  31  total_rec_prncp              54231 non-null  float64
#  32  total_rec_int                54231 non-null  float64
#  33  total_rec_late_fee           54231 non-null  float64
#  34  recoveries                   54231 non-null  float64
#  35  collection_recovery_fee      54231 non-null  float64
#  36  last_payment_date            54158 non-null  object
#  37  last_payment_amount          54231 non-null  float64
#  38  next_payment_date            21623 non-null  object
#  39  last_credit_pull_date        54224 non-null  object
#  40  collections_12_mths_ex_med   54180 non-null  float64
#  41  mths_since_last_major_derog  7499 non-null   float64
#  42  policy_code                  54231 non-null  int64
#  43  application_type             54231 non-null  object
# dtypes: float64(20), int64(9), object(15)
# memory usage: 18.2+ MB

# %%
print(loan_payments_df.iloc[0])
print(loan_payments_df.iloc[1])
print(loan_payments_df.iloc[2])
print(loan_payments_df.iloc[3000])
print(loan_payments_df.iloc[35])
print(loan_payments_df.iloc[92])
# Out:
# Unnamed: 0                                0
# id                                 38676116
# member_id                          41461848
# loan_amount                            8000
# funded_amount                        8000.0
# funded_amount_inv                    8000.0
# term                              36 months
# int_rate                               7.49
# instalment                           248.82
# grade                                     A
# sub_grade                                A4
# employment_length                   5 years
# home_ownership                     MORTGAGE
# annual_inc                          46000.0
# verification_status            Not Verified
# issue_date                         Jan-2021
# loan_status                         Current
# payment_plan                              n
# purpose                         credit_card
# dti                                   19.54
# delinq_2yrs                               2
# earliest_credit_line               Oct-1987
# inq_last_6mths                            1
# mths_since_last_delinq                  5.0
# mths_since_last_record                  NaN
# open_accounts                            12
# total_accounts                           27
# out_prncp                            5529.7
# out_prncp_inv                        5529.7
# total_payment                       2982.51
# total_payment_inv                   2982.51
# total_rec_prncp                      2470.3
# total_rec_int                        512.21
# total_rec_late_fee                      0.0
# recoveries                              0.0
# collection_recovery_fee                 0.0
# last_payment_date                  Jan-2022
# last_payment_amount                  248.82
# next_payment_date                  Feb-2022
# last_credit_pull_date              Jan-2022
# collections_12_mths_ex_med              0.0
# mths_since_last_major_derog             5.0
# policy_code                               1
# application_type                 INDIVIDUAL
# Name: 0, dtype: object
# Unnamed: 0                                1
# id                                 38656203
# member_id                          41440010
# loan_amount                           13200
# funded_amount                       13200.0
# funded_amount_inv                   13200.0
# term                              36 months
# int_rate                               6.99
# instalment                           407.52
# grade                                     A
# sub_grade                                A3
# employment_length                   9 years
# home_ownership                         RENT
# annual_inc                          50000.0
# verification_status            Not Verified
# issue_date                         Jan-2021
# loan_status                         Current
# payment_plan                              n
# purpose                         credit_card
# dti                                    24.2
# delinq_2yrs                               0
# earliest_credit_line               Sep-2001
# inq_last_6mths                            0
# mths_since_last_delinq                  NaN
# mths_since_last_record                  NaN
# open_accounts                            15
# total_accounts                           31
# out_prncp                           9102.83
# out_prncp_inv                       9102.83
# total_payment                       4885.11
# total_payment_inv                   4885.11
# total_rec_prncp                     4097.17
# total_rec_int                        787.94
# total_rec_late_fee                      0.0
# recoveries                              0.0
# collection_recovery_fee                 0.0
# last_payment_date                  Jan-2022
# last_payment_amount                  407.52
# next_payment_date                  Feb-2022
# last_credit_pull_date              Jan-2022
# collections_12_mths_ex_med              0.0
# mths_since_last_major_derog             NaN
# policy_code                               1
# application_type                 INDIVIDUAL
# Name: 1, dtype: object
# Unnamed: 0                                   2
# id                                    38656154
# member_id                             41439961
# loan_amount                              16000
# funded_amount                          16000.0
# funded_amount_inv                      16000.0
# term                                 36 months
# int_rate                                  7.49
# instalment                              497.63
# grade                                        A
# sub_grade                                   A4
# employment_length                      8 years
# home_ownership                        MORTGAGE
# annual_inc                             73913.0
# verification_status            Source Verified
# issue_date                            Jan-2021
# loan_status                         Fully Paid
# payment_plan                                 n
# purpose                            credit_card
# dti                                      16.92
# delinq_2yrs                                  0
# earliest_credit_line                  Sep-1998
# inq_last_6mths                               0
# mths_since_last_delinq                    69.0
# mths_since_last_record                     NaN
# open_accounts                                7
# total_accounts                              18
# out_prncp                                  0.0
# out_prncp_inv                              0.0
# total_payment                         16824.54
# total_payment_inv                     16824.54
# total_rec_prncp                        16000.0
# total_rec_int                           824.54
# total_rec_late_fee                         0.0
# recoveries                                 0.0
# collection_recovery_fee                    0.0
# last_payment_date                     Oct-2021
# last_payment_amount                   12850.16
# next_payment_date                          NaN
# last_credit_pull_date                 Oct-2021
# collections_12_mths_ex_med                 0.0
# mths_since_last_major_derog                NaN
# policy_code                                  1
# application_type                    INDIVIDUAL
# Name: 2, dtype: object
# Unnamed: 0                             3000
# id                                 37998162
# member_id                          40760877
# loan_amount                           12000
# funded_amount                       12000.0
# funded_amount_inv                   12000.0
# term                              36 months
# int_rate                               7.49
# instalment                           373.22
# grade                                     A
# sub_grade                                A4
# employment_length                   3 years
# home_ownership                     MORTGAGE
# annual_inc                          89000.0
# verification_status            Not Verified
# issue_date                         Jan-2021
# loan_status                      Fully Paid
# payment_plan                              n
# purpose                             medical
# dti                                   13.86
# delinq_2yrs                               0
# earliest_credit_line               Apr-2003
# inq_last_6mths                            1
# mths_since_last_delinq                 55.0
# mths_since_last_record                  NaN
# open_accounts                             9
# total_accounts                           15
# out_prncp                               0.0
# out_prncp_inv                           0.0
# total_payment                      12453.61
# total_payment_inv                  12453.61
# total_rec_prncp                     12000.0
# total_rec_int                        453.61
# total_rec_late_fee                      0.0
# recoveries                              0.0
# collection_recovery_fee                 0.0
# last_payment_date                  Aug-2021
# last_payment_amount                   25.41
# next_payment_date                       NaN
# last_credit_pull_date              Aug-2021
# collections_12_mths_ex_med              0.0
# mths_since_last_major_derog            67.0
# policy_code                               1
# application_type                 INDIVIDUAL
# Name: 3000, dtype: object
# Unnamed: 0                                     35
# id                                       38655432
# member_id                                41439228
# loan_amount                                  8800
# funded_amount                              8800.0
# funded_amount_inv                          8800.0
# term                                          NaN
# int_rate                                    16.49
# instalment                                 311.52
# grade                                           D
# sub_grade                                      D3
# employment_length                       10+ years
# home_ownership                               RENT
# annual_inc                                67000.0
# verification_status               Source Verified
# issue_date                               Jan-2021
# loan_status                               Current
# payment_plan                                    n
# purpose                        debt_consolidation
# dti                                         19.27
# delinq_2yrs                                     0
# earliest_credit_line                     May-1990
# inq_last_6mths                                  2
# mths_since_last_delinq                       44.0
# mths_since_last_record                        NaN
# open_accounts                                   9
# total_accounts                                 22
# out_prncp                                 6331.85
# out_prncp_inv                             6331.85
# total_payment                             3730.18
# total_payment_inv                         3730.18
# total_rec_prncp                           2468.15
# total_rec_int                             1262.03
# total_rec_late_fee                            0.0
# recoveries                                    0.0
# collection_recovery_fee                       0.0
# last_payment_date                        Jan-2022
# last_payment_amount                        311.52
# next_payment_date                        Feb-2022
# last_credit_pull_date                    Jan-2022
# collections_12_mths_ex_med                    0.0
# mths_since_last_major_derog                  44.0
# policy_code                                     1
# application_type                       INDIVIDUAL
# Name: 35, dtype: object
# Unnamed: 0                                     92
# id                                       38645682
# member_id                                41429484
# loan_amount                                 15875
# funded_amount                             15875.0
# funded_amount_inv                         15875.0
# term                                    36 months
# int_rate                                    16.49
# instalment                                 561.97
# grade                                           D
# sub_grade                                      D3
# employment_length                             NaN
# home_ownership                           MORTGAGE
# annual_inc                                46750.0
# verification_status                      Verified
# issue_date                               Jan-2021
# loan_status                            Fully Paid
# payment_plan                                    n
# purpose                        debt_consolidation
# dti                                         29.63
# delinq_2yrs                                     0
# earliest_credit_line                     Oct-2007
# inq_last_6mths                                  0
# mths_since_last_delinq                        NaN
# mths_since_last_record                       73.0
# open_accounts                                  11
# total_accounts                                 20
# out_prncp                                     0.0
# out_prncp_inv                                 0.0
# total_payment                            16417.22
# total_payment_inv                        16417.22
# total_rec_prncp                           15875.0
# total_rec_int                              542.22
# total_rec_late_fee                            0.0
# recoveries                                    0.0
# collection_recovery_fee                       0.0
# last_payment_date                        Mar-2021
# last_payment_amount                      15869.79
# next_payment_date                             NaN
# last_credit_pull_date                    Jan-2022
# collections_12_mths_ex_med                    0.0
# mths_since_last_major_derog                   NaN
# policy_code                                     1
# application_type                       INDIVIDUAL
# Name: 92, dtype: object

# %%
print(loan_payments_df['verification_status'].unique())
print(loan_payments_df['home_ownership'].unique())
print(loan_payments_df['loan_status'].unique())
print(loan_payments_df['purpose'].unique())
print(loan_payments_df['payment_plan'].unique())
print(loan_payments_df['application_type'].unique())

# %%
print(loan_payments_df.iloc[:,11]) 
print(loan_payments_df.iloc[:,6])

# %%
column_names = loan_payments_df.columns.tolist()
print(type(column_names))
print(len(column_names))
print(column_names)
